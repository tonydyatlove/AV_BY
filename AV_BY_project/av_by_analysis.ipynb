# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_2022_2024 = pd.read_csv('data_2022_2024_2.csv', sep=';', encoding='utf8')

# %%
df_2022_2024
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8398/98...
# 1              1  https://avcdn.av.by/advertpreview/0002/8395/58...
# 2              2  https://avcdn.av.by/advertpreview/0002/1416/30...
# 3              3  https://avcdn.av.by/advertpreview/0002/6856/65...
# 4              4  https://avcdn.av.by/advertpreview/0002/8227/10...
# ...          ...                                                ...
# 2298        2298  https://avcdn.av.by/advertpreview/0001/7303/34...
# 2299        2299  https://avcdn.av.by/advertpreview/0001/9097/91...
# 2300        2300  https://avcdn.av.by/advertpreview/0001/8652/21...
# 2301        2301  https://avcdn.av.by/advertpreview/0001/8858/98...
# 2302        2302  https://avcdn.av.by/advertpreview/0001/3173/22...
#
#                           car_name  \
# 0                  Volkswagen ID.4
# 1                          Zeekr X
# 2          Audi Q7 4M · Рестайлинг
# ...

# %%
df_2021 = pd.read_csv('data_2021_2.csv', sep=';', encoding='utf8')

# %%
df_2021
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/3128/27...
# 1              1  https://avcdn.av.by/advertpreview/0002/5545/78...
# 2              2  https://avcdn.av.by/advertpreview/0002/6687/27...
# 3              3  https://avcdn.av.by/advertpreview/0002/7332/34...
# 4              4  https://avcdn.av.by/advertpreview/0002/8326/33...
# ...          ...                                                ...
# 1728        1728  https://avcdn.av.by/advertpreview/0002/2270/70...
# 1729        1729  https://avcdn.av.by/advertpreview/0001/9316/75...
# 1730        1730  https://avcdn.av.by/advertpreview/0001/2634/06...
# 1731        1731  https://avcdn.av.by/advertpreview/0000/7746/84...
# 1732        1732  https://avcdn.av.by/advertpreview/0001/2589/28...
#
#                                           car_name  \
# 0                                       BMW X3 G01
# ...

# %%
df_2020_not_auto_gearbox = pd.read_csv('data_2020_notauto_gearbox.csv', sep=';', encoding='utf8')

# %%
df_2020_not_auto_gearbox
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8183/40...
# 1              1  https://avcdn.av.by/advertpreview/0002/7772/50...
# 2              2  https://avcdn.av.by/advertpreview/0002/8095/34...
# 3              3  https://avcdn.av.by/advertpreview/0002/7564/34...
# 4              4  https://avcdn.av.by/advertpreview/0002/8303/68...
# ...          ...                                                ...
# 1526        1526  https://avcdn.av.by/advertpreview/0001/4308/27...
# 1527        1527  https://avcdn.av.by/advertpreview/0001/8105/17...
# 1528        1528  https://avcdn.av.by/advertpreview/0002/0962/78...
# 1529        1529  https://avcdn.av.by/advertpreview/0001/0680/07...
# 1530        1530  https://avcdn.av.by/advertpreview/0000/6689/22...
#
#                                  car_name  \
# 0     Geely Emgrand X7 I · 2-й рестайлинг
# 1                Volkswagen Caddy MAXI IV
# ...

# %%
df_2020_auto_gearbox = pd.read_csv('data_2020_auto_gearbox.csv', sep=';', encoding='utf8')

# %%
df_2020_auto_gearbox
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/6742/70...
# 1              1  https://avcdn.av.by/advertpreview/0002/8124/80...
# 2              2  https://avcdn.av.by/advertpreview/0002/7443/89...
# 3              3  https://avcdn.av.by/advertpreview/0002/6859/63...
# 4              4  https://avcdn.av.by/advertpreview/0002/7941/85...
# ...          ...                                                ...
# 2384        2384  https://avcdn.av.by/advertpreview/0001/9797/59...
# 2385        2385  https://avcdn.av.by/advertpreview/0001/8136/77...
# 2386        2386  https://avcdn.av.by/advertpreview/0002/6385/74...
# 2387        2387  https://avcdn.av.by/advertpreview/0001/7891/57...
# 2388        2388  https://avcdn.av.by/advertpreview/0000/6039/01...
#
#                                       car_name  \
# 0                     Volkswagen Multivan T6.1
# 1                                   BMW X5 G05
# ...

# %%
df_2019_to_18000 = pd.read_csv('data_2019_to_18000.csv', sep=';', encoding='utf8')

# %%
df_2019_to_18000
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8223/30...
# 1              1  https://avcdn.av.by/advertpreview/0002/8169/36...
# 2              2  https://avcdn.av.by/advertpreview/0002/8226/04...
# 3              3  https://avcdn.av.by/advertpreview/0002/8092/16...
# 4              4  https://avcdn.av.by/advertpreview/0002/8292/93...
# ...          ...                                                ...
# 2759        2759  https://avcdn.av.by/advertpreview/0002/0968/48...
# 2760        2760  https://avcdn.av.by/advertpreview/0002/0061/53...
# 2761        2761  https://avcdn.av.by/advertpreview/0002/0047/89...
# 2762        2762  https://avcdn.av.by/advertpreview/0001/9250/64...
# 2763        2763  https://avcdn.av.by/advertpreview/0001/6403/92...
#
#                                   car_name  \
# 0                  Citroen C4 Spacetourer
# 1              Peugeot 308 T9 · Рестайлинг
# ...

# %%
df_2019_from_18001_to_27000 = pd.read_csv('data_2019_from_18001_to_27000.csv', sep=';', encoding='utf8')

# %%
df_2019_from_18001_to_27000
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8069/30...
# 1              1  https://avcdn.av.by/advertpreview/0002/8025/60...
# 2              2  https://avcdn.av.by/advertpreview/0002/8229/88...
# 3              3  https://avcdn.av.by/advertpreview/0002/6802/51...
# 4              4  https://avcdn.av.by/advertpreview/0002/7438/77...
# ...          ...                                                ...
# 2910        2910  https://avcdn.av.by/advertpreview/0002/3383/02...
# 2911        2911  https://avcdn.av.by/advertpreview/0002/0935/21...
# 2912        2912  https://avcdn.av.by/advertpreview/0001/7976/77...
# 2913        2913  https://avcdn.av.by/advertpreview/0002/6716/85...
# 2914        2914  https://avcdn.av.by/advertpreview/0001/8868/50...
#
#                                                car_name  \
# 0                                 Citroen C5 Aircross I
# ...

# %%
df_2019_from_27001 = pd.read_csv('data_2019_from_27001.csv', sep=';', encoding='utf8')

# %%
df_2019_from_27001
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/7980/04...
# 1              1  https://avcdn.av.by/advertpreview/0002/8130/36...
# 2              2  https://avcdn.av.by/advertpreview/0002/7921/49...
# 3              3  https://avcdn.av.by/advertpreview/0002/7922/46...
# 4              4  https://avcdn.av.by/advertpreview/0002/7928/18...
# ...          ...                                                ...
# 2670        2670  https://avcdn.av.by/advertpreview/0001/6633/93...
# 2671        2671  https://avcdn.av.by/advertpreview/0001/6280/89...
# 2672        2672  https://avcdn.av.by/advertpreview/0002/0568/34...
# 2673        2673  https://avcdn.av.by/advertpreview/0001/4480/76...
# 2674        2674  https://avcdn.av.by/advertpreview/0000/6689/86...
#
#                                 car_name  \
# 0                                Audi Q8
# 1                           Honda CR-V V
# ...

# %%
df_2018_to_20000 = pd.read_csv('data_2018_to_20000.csv', sep=';', encoding='utf8')

# %%
df_2018_to_20000
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8202/77...
# 1              1  https://avcdn.av.by/advertpreview/0002/8323/84...
# 2              2  https://avcdn.av.by/advertpreview/0002/8305/54...
# 3              3  https://avcdn.av.by/advertpreview/0002/8346/10...
# 4              4  https://avcdn.av.by/advertpreview/0002/4527/92...
# ...          ...                                                ...
# 3017        3017  https://avcdn.av.by/advertpreview/0002/4809/31...
# 3018        3018  https://avcdn.av.by/advertpreview/0001/8472/42...
# 3019        3019  https://avcdn.av.by/advertpreview/0002/3488/84...
# 3020        3020  https://avcdn.av.by/advertpreview/0002/6414/59...
# 3021        3021  https://avcdn.av.by/advertpreview/0001/6706/01...
#
#                            car_name  \
# 0              Volkswagen Passat B8
# 1                     Ford Focus IV
# 2              Volkswagen Jetta VII
# ...

# %%
df_2018_from_20001 = pd.read_csv('data_2018_from_20001.csv', sep=';', encoding='utf8')

# %%
df_2018_from_20001
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/7845/70...
# 1              1  https://avcdn.av.by/advertpreview/0002/8219/00...
# 2              2  https://avcdn.av.by/advertpreview/0002/8365/28...
# 3              3  https://avcdn.av.by/advertpreview/0002/6946/99...
# 4              4  https://avcdn.av.by/advertpreview/0002/6957/41...
# ...          ...                                                ...
# 2853        2853  https://avcdn.av.by/advertpreview/0002/7902/53...
# 2854        2854  https://avcdn.av.by/advertpreview/0000/7436/69...
# 2855        2855  https://avcdn.av.by/advertpreview/0001/7801/63...
# 2856        2856  https://avcdn.av.by/advertpreview/0001/6907/14...
# 2857        2857  https://avcdn.av.by/advertpreview/0002/0664/39...
#
#                                               car_name  \
# 0                               Mercedes-Benz GLC X253
# ...

# %%
df_2017 = pd.read_csv('data_2017.csv', sep=';', encoding='utf8')

# %%
df_2017
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/6165/72...
# 1              1  https://avcdn.av.by/advertpreview/0002/7955/65...
# 2              2  https://avcdn.av.by/advertpreview/0002/8327/23...
# 3              3  https://avcdn.av.by/advertpreview/0002/8328/92...
# 4              4  https://avcdn.av.by/advertpreview/0002/8304/16...
# ...          ...                                                ...
# 2885        2885  https://avcdn.av.by/advertpreview/0002/1818/48...
# 2886        2886  https://avcdn.av.by/advertpreview/0001/4333/35...
# 2887        2887  https://avcdn.av.by/advertpreview/0001/8458/05...
# 2888        2888  https://avcdn.av.by/advertpreview/0001/2213/45...
# 2889        2889  https://avcdn.av.by/advertpreview/0000/3785/28...
#
#                                               car_name  \
# 0     Citroen C4 Grand Picasso II · Рестайлинг, 7 мест
# ...

# %%
df_2016 = pd.read_csv('data_2016.csv', sep=';', encoding='utf8')

# %%
df_2016
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8387/25...
# 1              1  https://avcdn.av.by/advertpreview/0002/8130/97...
# 2              2  https://avcdn.av.by/advertpreview/0002/8327/49...
# 3              3  https://avcdn.av.by/advertpreview/0002/6353/85...
# 4              4  https://avcdn.av.by/advertpreview/0002/7329/33...
# ...          ...                                                ...
# 2129        2129  https://avcdn.av.by/advertpreview/0002/1336/87...
# 2130        2130  https://avcdn.av.by/advertpreview/0002/0382/18...
# 2131        2131  https://avcdn.av.by/advertpreview/0002/0173/59...
# 2132        2132  https://avcdn.av.by/advertpreview/0001/0686/97...
# 2133        2133  https://avcdn.av.by/advertpreview/0002/0594/09...
#
#                         car_name  \
# 0             Lada (ВАЗ) Vesta I
# 1             Hyundai Tucson III
# 2                 Kia Carens III
# ...

# %%
df_2015 = pd.read_csv('data_2015_1.csv', sep=';', encoding='utf8')

# %%
df_2015
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8203/40...
# 1              1  https://avcdn.av.by/advertpreview/0002/7793/48...
# 2              2  https://avcdn.av.by/advertpreview/0002/7233/25...
# 3              3  https://avcdn.av.by/advertpreview/0002/8105/55...
# 4              4  https://avcdn.av.by/advertpreview/0002/6289/36...
# ...          ...                                                ...
# 1886        1886  https://avcdn.av.by/advertpreview/0001/7628/28...
# 1887        1887  https://avcdn.av.by/advertpreview/0001/7153/44...
# 1888        1888  https://avcdn.av.by/advertpreview/0001/8577/97...
# 1889        1889  https://avcdn.av.by/advertpreview/0001/1813/36...
# 1890        1890  https://avcdn.av.by/advertpreview/0001/2201/81...
#
#                                        car_name  \
# 0                      Nissan X-Trail III (T32)
# 1     Mitsubishi Outlander III · 2-й рестайлинг
# ...

# %%
df_2014 = pd.read_csv('data_2014.csv', sep=';', encoding='utf8')

# %%
df_2014
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8306/66...
# 1              1  https://avcdn.av.by/advertpreview/0002/8339/49...
# 2              2  https://avcdn.av.by/advertpreview/0002/8028/49...
# 3              3  https://avcdn.av.by/advertpreview/0002/8252/15...
# 4              4  https://avcdn.av.by/advertpreview/0002/8327/10...
# ...          ...                                                ...
# 2105        2105  https://avcdn.av.by/advertpreview/0001/9739/61...
# 2106        2106  https://avcdn.av.by/advertpreview/0002/3057/36...
# 2107        2107  https://avcdn.av.by/advertpreview/0001/2366/75...
# 2108        2108  https://avcdn.av.by/advertpreview/0001/6015/29...
# 2109        2109  https://avcdn.av.by/advertpreview/0001/4104/74...
#
#                                 car_name  \
# 0                           Ford Kuga II
# 1                Audi A8 D4 · Рестайлинг
# ...

# %%
df_2013 = pd.read_csv('data_2013.csv', sep=';', encoding='utf8')

# %%
df_2013
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/7729/77...
# 1              1  https://avcdn.av.by/advertpreview/0002/8239/77...
# 2              2  https://avcdn.av.by/advertpreview/0002/7351/64...
# 3              3  https://avcdn.av.by/advertpreview/0002/8175/11...
# 4              4  https://avcdn.av.by/advertpreview/0002/2793/53...
# ...          ...                                                ...
# 1823        1823  https://avcdn.av.by/advertpreview/0001/8238/15...
# 1824        1824  https://avcdn.av.by/advertpreview/0001/7598/03...
# 1825        1825  https://avcdn.av.by/advertpreview/0001/7523/66...
# 1826        1826  https://avcdn.av.by/advertpreview/0000/5352/67...
# 1827        1827  https://avcdn.av.by/advertpreview/0002/7791/68...
#
#                                   car_name  \
# 0                   Toyota Auris II (E180)
# 1                        Toyota Camry XV50
# ...

# %%
df_2012 = pd.read_csv('data_2012.csv', sep=';', encoding='utf8')

# %%
df_2012
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/7983/95...
# 1              1  https://avcdn.av.by/advertpreview/0002/7078/49...
# 2              2  https://avcdn.av.by/advertpreview/0002/8293/08...
# 3              3  https://avcdn.av.by/advertpreview/0002/8326/46...
# 4              4  https://avcdn.av.by/advertpreview/0002/7327/15...
# ...          ...                                                ...
# 1707        1707  https://avcdn.av.by/advertpreview/0002/0732/90...
# 1708        1708  https://avcdn.av.by/advertpreview/0002/1718/40...
# 1709        1709  https://avcdn.av.by/advertpreview/0002/1448/16...
# 1710        1710  https://avcdn.av.by/advertpreview/0002/1421/09...
# 1711        1711  https://avcdn.av.by/advertpreview/0000/7809/46...
#
#                              car_name  \
# 0     Renault Megane III · Рестайлинг
# 1                       Citroen C4 II
# ...

# %%
df_2011 = pd.read_csv('data_2011.csv', sep=';', encoding='utf8')

# %%
df_2011
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8173/70...
# 1              1  https://avcdn.av.by/advertpreview/0002/8205/49...
# 2              2  https://avcdn.av.by/advertpreview/0002/5699/16...
# 3              3  https://avcdn.av.by/advertpreview/0002/8280/24...
# 4              4  https://avcdn.av.by/advertpreview/0002/8171/28...
# ...          ...                                                ...
# 2104        2104  https://avcdn.av.by/advertpreview/0001/3285/74...
# 2105        2105  https://avcdn.av.by/advertpreview/0001/3327/68...
# 2106        2106  https://static.av.by/public_images/preview/016...
# 2107        2107  https://avcdn.av.by/advertpreview/0000/7597/16...
# 2108        2108  https://avcdn.av.by/advertpreview/0000/7603/19...
#
#                                    car_name  \
# 0                             Ford C-MAX II
# 1               Ford Mondeo IV · Рестайлинг
# ...

# %%
df_2010 = pd.read_csv('data_2010.csv', sep=';', encoding='utf8')

# %%
df_2010
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8175/13...
# 1              1  https://avcdn.av.by/advertpreview/0002/8230/30...
# 2              2  https://avcdn.av.by/advertpreview/0002/8325/13...
# 3              3  https://avcdn.av.by/advertpreview/0002/7774/26...
# 4              4  https://avcdn.av.by/advertpreview/0002/8097/77...
# ...          ...                                                ...
# 2370        2370  https://avcdn.av.by/advertpreview/0001/7705/87...
# 2371        2371  https://avcdn.av.by/advertpreview/0001/9688/17...
# 2372        2372  https://avcdn.av.by/advertpreview/0002/0084/28...
# 2373        2373  https://avcdn.av.by/advertpreview/0001/1350/59...
# 2374        2374  https://avcdn.av.by/advertpreview/0000/2824/48...
#
#                                       car_name  \
# 0               Toyota Camry XV40 · Рестайлинг
# 1           Opel Zafira B · Рестайлинг, 7 мест
# ...

# %%
df = df_2022_2024.append(df_2021).append(df_2020_not_auto_gearbox).append(df_2020_auto_gearbox).append(df_2019_to_18000).append(df_2019_from_18001_to_27000).append(df_2019_from_27001).append(df_2018_to_20000).append(df_2018_from_20001).append(df_2017).append(df_2016).append(df_2015).append(df_2014).append(df_2013).append(df_2012).append(df_2011).append(df_2010)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16456\12330909.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_2022_2024.append(df_2021).append(df_2020_not_auto_gearbox).append(df_2020_auto_gearbox).append(df_2019_to_18000).append(df_2019_from_18001_to_27000).append(df_2019_from_27001).append(df_2018_to_20000).append(df_2018_from_20001).append(df_2017).append(df_2016).append(df_2015).append(df_2014).append(df_2013).append(df_2012).append(df_2011).append(df_2010)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16456\12330909.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df
# Out:
#       Unnamed: 0                                              image  \
# 0              0  https://avcdn.av.by/advertpreview/0002/8398/98...
# 1              1  https://avcdn.av.by/advertpreview/0002/8395/58...
# 2              2  https://avcdn.av.by/advertpreview/0002/1416/30...
# 3              3  https://avcdn.av.by/advertpreview/0002/6856/65...
# 4              4  https://avcdn.av.by/advertpreview/0002/8227/10...
# ...          ...                                                ...
# 2370        2370  https://avcdn.av.by/advertpreview/0001/7705/87...
# 2371        2371  https://avcdn.av.by/advertpreview/0001/9688/17...
# 2372        2372  https://avcdn.av.by/advertpreview/0002/0084/28...
# 2373        2373  https://avcdn.av.by/advertpreview/0001/1350/59...
# 2374        2374  https://avcdn.av.by/advertpreview/0000/2824/48...
#
#                                       car_name  \
# 0                              Volkswagen ID.4
# 1                                      Zeekr X
# ...

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df['price_in_byn'] = df['price_in_byn'].str.replace(r'[\s\xa0р.]', '', regex=True).astype(int)

# %%
df.dtypes
# Out:
# image           object
# car_name        object
# car_info        object
# price_in_byn     int32
# price_in_usd    object
# city            object
# date            object
# dtype: object

# %%
df['price_in_usd'] = df['price_in_usd'].str.replace(r'[\s≈$]', '', regex=True).astype(int)

# %%
df
# Out:
#                                                   image  \
# 0     https://avcdn.av.by/advertpreview/0002/8398/98...
# 1     https://avcdn.av.by/advertpreview/0002/8395/58...
# 2     https://avcdn.av.by/advertpreview/0002/1416/30...
# 3     https://avcdn.av.by/advertpreview/0002/6856/65...
# 4     https://avcdn.av.by/advertpreview/0002/8227/10...
# ...                                                 ...
# 2370  https://avcdn.av.by/advertpreview/0001/7705/87...
# 2371  https://avcdn.av.by/advertpreview/0001/9688/17...
# 2372  https://avcdn.av.by/advertpreview/0002/0084/28...
# 2373  https://avcdn.av.by/advertpreview/0001/1350/59...
# 2374  https://avcdn.av.by/advertpreview/0000/2824/48...
#
#                                       car_name  \
# 0                              Volkswagen ID.4
# 1                                      Zeekr X
# 2                      Audi Q7 4M · Рестайлинг
# 3                              Volkswagen ID.3
# 4                                   Honda eNS1
# ...

# %%
unique_rows_count = df.nunique()

# %%
unique_rows_count
# Out:
# image           38391
# car_name         1974
# car_info        34108
# price_in_byn     3151
# price_in_usd     3138
# city              137
# date              696
# dtype: int64

# %%
duplicate_rows = df[df.duplicated(subset='image', keep=False)]

# %%
duplicate_rows
# Out:
#                                                   image  \
# 0     https://avcdn.av.by/advertpreview/0002/8398/98...
# 1     https://avcdn.av.by/advertpreview/0002/8395/58...
# 2     https://avcdn.av.by/advertpreview/0002/1416/30...
# 3     https://avcdn.av.by/advertpreview/0002/6856/65...
# 4     https://avcdn.av.by/advertpreview/0002/8227/10...
# ...                                                 ...
# 1320                                                  -
# 1868                                                  -
# 1976                                                  -
# 2026                                                  -
# 2112                                                  -
#
#                                  car_name  \
# 0                         Volkswagen ID.4
# 1                                 Zeekr X
# 2                 Audi Q7 4M · Рестайлинг
# 3                         Volkswagen ID.3
# 4                              Honda eNS1
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
duplicate_rows['image'].values[1]
# Out:
# 'https://avcdn.av.by/advertpreview/0002/8395/5824.jpg'

# %%
duplicate_rows.loc[duplicate_rows['image'] == '-'].count()
# Out:
# image           95
# car_name        95
# car_info        95
# price_in_byn    95
# price_in_usd    95
# city            95
# date            95
# dtype: int64

# %%
duplicate_rows_1 = duplicate_rows.loc[duplicate_rows['image'] == '-'].drop_duplicates(subset=['car_info', 'city']).count()

# %%
duplicate_rows_1
# Out:
# image           92
# car_name        92
# car_info        92
# price_in_byn    92
# price_in_usd    92
# city            92
# date            92
# dtype: int64
